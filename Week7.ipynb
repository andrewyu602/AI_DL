# %% [markdown]
# <a href="https://colab.research.google.com/github/andrewyu602/AI_DL/blob/main/Week7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist

def get_mnist_model():
    inputs = keras.Input(shape=(28 * 28,))
    features = layers.Dense(512, activation="relu")(inputs)
    features = layers.Dropout(0.5)(features)
    outputs = layers.Dense(10, activation="softmax")(features)
    model = keras.Model(inputs, outputs)
    return model

(images, labels), (test_images, test_labels) = mnist.load_data()
images = images.reshape((60000, 28 * 28)).astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28)).astype("float32") / 255
train_images, val_images = images[10000:], images[:10000]
train_labels, val_labels = labels[10000:], labels[:10000]

# %% [markdown]
# # Metrics

# %%
from keras import ops
class RootMeanSquaredError(keras.metrics.Metric): #1
  def __init__(self, name="rmse", **kwargs): #2
    super().__init__(name=name, **kwargs) #2
    self.mse_sum = self.add_weight(name="mse_sum", initializer="zeros") #2
    self.total_samples = self.add_weight( #2
      name="total_samples", initializer="zeros") #2

  def update_state(self, y_true, y_pred, sample_weight=None): #3
    y_true = ops.one_hot(y_true, num_classes=ops.shape(y_pred)[1]) #3
    mse = ops.sum(ops.square(y_true - y_pred)) #3
    self.mse_sum.assign_add(mse) #3
    num_samples = ops.shape(y_pred)[0] #3
    self.total_samples.assign_add(num_samples) #3

  def result(self):
    return ops.sqrt(self.mse_sum / self.total_samples)

  def reset_state(self):
    self.mse_sum.assign(0.)
    self.total_samples.assign(0)

# %%
import numpy as np
m = RootMeanSquaredError()
m.update_state(np.array([0, 1]), np.array([[0.05, 0.95, 0], [0.1, 0.8, 0.1]]))
m.result()
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.9656603336334229>

# %%
model = get_mnist_model()
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy", RootMeanSquaredError()])
model.fit(train_images, train_labels,
          epochs=3,
          validation_data=(val_images, val_labels))
test_metrics = model.evaluate(test_images, test_labels)
# Out:
# Epoch 1/3
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8584 - loss: 0.4616 - rmse: 0.4428 - val_accuracy: 0.9582 - val_loss: 0.1440 - val_rmse: 0.2510
# Epoch 2/3
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9526 - loss: 0.1660 - rmse: 0.2709 - val_accuracy: 0.9683 - val_loss: 0.1119 - val_rmse: 0.2198
# Epoch 3/3
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9637 - loss: 0.1342 - rmse: 0.2408 - val_accuracy: 0.9702 - val_loss: 0.1097 - val_rmse: 0.2134
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9695 - loss: 0.1099 - rmse: 0.2141

# %% [markdown]
# # Callback

# %%
model = get_mnist_model()
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
model.fit(train_images, train_labels,
          epochs=3,
          validation_data=(val_images, val_labels))
test_metrics = model.evaluate(test_images, test_labels)
predictions = model.predict(test_images)
# Out:
# Epoch 1/3
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8630 - loss: 0.4525 - val_accuracy: 0.9588 - val_loss: 0.1465
# Epoch 2/3
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9522 - loss: 0.1689 - val_accuracy: 0.9669 - val_loss: 0.1140
# Epoch 3/3
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9659 - loss: 0.1256 - val_accuracy: 0.9712 - val_loss: 0.1048
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9711 - loss: 0.1138
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
callbacks_list = [
    keras.callbacks.EarlyStopping(
        monitor="val_accuracy",
        patience=2,
    ),
    keras.callbacks.ModelCheckpoint(
        filepath="checkpoint_path.keras",
        monitor="val_loss",
        save_best_only=True,
    )
]
model = get_mnist_model()
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
model.fit(train_images, train_labels,
          epochs=10,
          callbacks=callbacks_list,
          validation_data=(val_images, val_labels))
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8645 - loss: 0.4466 - val_accuracy: 0.9563 - val_loss: 0.1473
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9520 - loss: 0.1677 - val_accuracy: 0.9688 - val_loss: 0.1155
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9630 - loss: 0.1304 - val_accuracy: 0.9723 - val_loss: 0.1042
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9691 - loss: 0.1122 - val_accuracy: 0.9770 - val_loss: 0.0933
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9715 - loss: 0.1013 - val_accuracy: 0.9773 - val_loss: 0.0927
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9732 - loss: 0.0963 - val_accuracy: 0.9776 - val_loss: 0.0914
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9764 - loss: 0.0850 - val_accuracy: 0.9785 - val_loss: 0.0929
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9770 - loss: 0.0846 - val_accuracy: 0.9778 - val_loss: 0.0979
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9783 - loss: 0.0801 - val_accuracy: 0.9798 - val_loss: 0.0910
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9810 - loss: 0.0671 - val_accuracy: 0.9782 - val_loss: 0.0989

# %%
model = keras.models.load_model("checkpoint_path.keras")

# %%
model.evaluate(val_images,val_labels)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9810 - loss: 0.0907
# [0.09097030758857727, 0.9797999858856201]

# %%
model.evaluate(test_images, test_labels)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9770 - loss: 0.1026
# [0.084803007543087, 0.9804999828338623]

# %% [markdown]
# # A complete Training and Evaluation Loop

# %%
model = get_mnist_model()

loss_fn = keras.losses.SparseCategoricalCrossentropy()
optimizer = keras.optimizers.RMSprop()
metrics = [keras.metrics.SparseCategoricalAccuracy()]
loss_tracking_metric = keras.metrics.Mean()

@tf.function
def train_step(inputs, targets):
    with tf.GradientTape() as tape:
        predictions = model(inputs, training=True) # For Training loop this must be true
        loss = loss_fn(targets, predictions)
    gradients = tape.gradient(loss, model.trainable_weights)
    optimizer.apply_gradients(zip(gradients, model.trainable_weights))

    logs = {}
    for metric in metrics:
        metric.update_state(targets, predictions)
        logs[metric.name] = metric.result()

    loss_tracking_metric.update_state(loss)
    logs["loss"] = loss_tracking_metric.result()
    return logs

# %%
def reset_metrics():
    for metric in metrics:
        metric.reset_state()
    loss_tracking_metric.reset_state()

# %%
training_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
training_dataset = training_dataset.batch(32)
epochs = 3
for epoch in range(epochs):
    reset_metrics()
    for inputs_batch, targets_batch in training_dataset:
        logs = train_step(inputs_batch, targets_batch)
    print(f"Results at the end of epoch {epoch}")
    for key, value in logs.items():
        print(f"...{key}: {value:.4f}")
# Out:
# Results at the end of epoch 0
# ...sparse_categorical_accuracy: 0.9130
# ...loss: 0.2916
# Results at the end of epoch 1
# ...sparse_categorical_accuracy: 0.9534
# ...loss: 0.1607
# Results at the end of epoch 2
# ...sparse_categorical_accuracy: 0.9641
# ...loss: 0.1312

# %%
training_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
training_dataset = training_dataset.batch(100)
epochs = 3
for epoch in range(epochs):
    reset_metrics()
    for inputs_batch, targets_batch in training_dataset:
        logs = train_step(inputs_batch, targets_batch)
        print("Results at the end of the batch")
        for key, value in logs.items():
          print(f"...{key}: {value:.4f}")

    print(f"Results at the end of epoch {epoch}")
    for key, value in logs.items():
        print(f"...{key}: {value:.4f}")
# Out:
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9700
# ...loss: 0.1778
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9700
# ...loss: 0.1453
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9467
# ...loss: 0.2097
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9575
# ...loss: 0.1730
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9640
# ...loss: 0.1451
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9683
# ...loss: 0.1306
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9700
# ...loss: 0.1206
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9650
# ...loss: 0.1394
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9656
# ...loss: 0.1380
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9650
# ...loss: 0.1394
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9664
# ...loss: 0.1317
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9675
# ...loss: 0.1245
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9685
# ...loss: 0.1224
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9700
# ...loss: 0.1154
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9707
# ...loss: 0.1118
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9706
# ...loss: 0.1108
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9712
# ...loss: 0.1091
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9694
# ...loss: 0.1170
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9679
# ...loss: 0.1198
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9680
# ...loss: 0.1194
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9681
# ...loss: 0.1174
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9686
# ...loss: 0.1141
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9687
# ...loss: 0.1117
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9692
# ...loss: 0.1114
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9696
# ...loss: 0.1092
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9673
# ...loss: 0.1267
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9659
# ...loss: 0.1342
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9661
# ...loss: 0.1312
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9662
# ...loss: 0.1286
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9660
# ...loss: 0.1281
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9652
# ...loss: 0.1303
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9644
# ...loss: 0.1294
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9652
# ...loss: 0.1290
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9653
# ...loss: 0.1281
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9651
# ...loss: 0.1274
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9658
# ...loss: 0.1267
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9657
# ...loss: 0.1271
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9658
# ...loss: 0.1259
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9662
# ...loss: 0.1246
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9657
# ...loss: 0.1258
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9656
# ...loss: 0.1249
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9660
# ...loss: 0.1242
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9660
# ...loss: 0.1245
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9650
# ...loss: 0.1260
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9656
# ...loss: 0.1244
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9654
# ...loss: 0.1247
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9651
# ...loss: 0.1247
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9640
# ...loss: 0.1285
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9643
# ...loss: 0.1276
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9646
# ...loss: 0.1260
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9645
# ...loss: 0.1252
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9646
# ...loss: 0.1250
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9647
# ...loss: 0.1244
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9646
# ...loss: 0.1239
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9699
# ...loss: 0.1023
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9700
# ...loss: 0.1021
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9700
# ...loss: 0.1019
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9699
# ...loss: 0.1022
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9699
# ...loss: 0.1020
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9700
# ...loss: 0.1018
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9701
# ...loss: 0.1016
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9701
# ...loss: 0.1015
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9701
# ...loss: 0.1014
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9701
# ...loss: 0.1012
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9702
# ...loss: 0.1010
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9702
# ...loss: 0.1009
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9701
# ...loss: 0.1017
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9702
# ...loss: 0.1015
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9702
# ...loss: 0.1018
# Results at the end of epoch 0
# ...sparse_categorical_accuracy: 0.9702
# ...loss: 0.1018
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9600
# ...loss: 0.0771
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9750
# ...loss: 0.0556
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9567
# ...loss: 0.1215
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9650
# ...loss: 0.0997
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9720
# ...loss: 0.0837
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9750
# ...loss: 0.0752
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9771
# ...loss: 0.0762
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0800
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9778
# ...loss: 0.0745
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9760
# ...loss: 0.0819
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9773
# ...loss: 0.0780
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9783
# ...loss: 0.0734
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9792
# ...loss: 0.0715
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9807
# ...loss: 0.0676
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9807
# ...loss: 0.0664
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9787
# ...loss: 0.0696
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9788
# ...loss: 0.0696
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9783
# ...loss: 0.0707
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9774
# ...loss: 0.0720
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9775
# ...loss: 0.0705
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9771
# ...loss: 0.0740
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9777
# ...loss: 0.0731
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9778
# ...loss: 0.0732
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9779
# ...loss: 0.0744
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9776
# ...loss: 0.0745
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0909
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9748
# ...loss: 0.0954
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9750
# ...loss: 0.0939
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9755
# ...loss: 0.0924
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9753
# ...loss: 0.0914
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9752
# ...loss: 0.0913
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9753
# ...loss: 0.0900
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9758
# ...loss: 0.0896
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9756
# ...loss: 0.0894
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9757
# ...loss: 0.0887
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9758
# ...loss: 0.0878
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9757
# ...loss: 0.0887
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9755
# ...loss: 0.0888
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9751
# ...loss: 0.0897
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9750
# ...loss: 0.0906
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9749
# ...loss: 0.0910
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9755
# ...loss: 0.0892
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9758
# ...loss: 0.0890
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9757
# ...loss: 0.0890
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0874
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0877
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0875
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9758
# ...loss: 0.0904
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9761
# ...loss: 0.0893
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0887
# Results at the end of the batch
# ...
# ...sparse_categorical_accuracy: 0.9761
# ...loss: 0.0794
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9761
# ...loss: 0.0793
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0792
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9761
# ...loss: 0.0792
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0791
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0789
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0792
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0793
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0798
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0798
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9761
# ...loss: 0.0800
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0800
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0802
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9761
# ...loss: 0.0803
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9761
# ...loss: 0.0802
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0800
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0798
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0797
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0797
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0797
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0796
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0796
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0798
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0797
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0797
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0798
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0799
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0803
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0802
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0801
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0800
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0803
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0803
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0803
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0803
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0802
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0801
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0800
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0801
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0803
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0802
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0804
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0805
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0805
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0805
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9761
# ...loss: 0.0810
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9761
# ...loss: 0.0810
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9761
# ...loss: 0.0811
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9761
# ...loss: 0.0809
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9761
# ...loss: 0.0808
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9761
# ...loss: 0.0809
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9761
# ...loss: 0.0808
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9761
# ...loss: 0.0807
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9761
# ...loss: 0.0807
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0806
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0808
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0806
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0807
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0805
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0808
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0808
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0807
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0807
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0806
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0805
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0804
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0803
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0802
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0802
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0802
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0800
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0800
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0802
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0802
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0802
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0802
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0801
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0800
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0803
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0805
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0804
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0811
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0810
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0810
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0808
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0811
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0812
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9761
# ...loss: 0.0813
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9761
# ...loss: 0.0816
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0815
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0814
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0813
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0812
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0811
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0810
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0813
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0812
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0811
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0810
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0810
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0810
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0809
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0809
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0808
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0808
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0809
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0808
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0808
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0807
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0806
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0807
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0809
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0814
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0813
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0813
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0813
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0813
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0813
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0812
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0813
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0812
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0811
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0811
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9762
# ...loss: 0.0812
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0811
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0810
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0810
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0808
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0810
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0809
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0808
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0809
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0810
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0809
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9763
# ...loss: 0.0808
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0807
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0807
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0807
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0806
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9765
# ...loss: 0.0805
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9765
# ...loss: 0.0807
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0807
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9765
# ...loss: 0.0806
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9765
# ...loss: 0.0805
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9765
# ...loss: 0.0804
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9765
# ...loss: 0.0805
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0804
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0805
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0804
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0804
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0803
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0802
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0801
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0801
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0800
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0800
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0799
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0798
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0797
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0798
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9764
# ...loss: 0.0798
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9765
# ...loss: 0.0796
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9765
# ...loss: 0.0796
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9765
# ...loss: 0.0795
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9765
# ...loss: 0.0794
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9766
# ...loss: 0.0793
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9766
# ...loss: 0.0791
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9767
# ...loss: 0.0790
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9767
# ...loss: 0.0789
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9767
# ...loss: 0.0788
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9767
# ...loss: 0.0787
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9767
# ...loss: 0.0788
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9767
# ...loss: 0.0787
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9768
# ...loss: 0.0785
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9768
# ...loss: 0.0784
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9768
# ...loss: 0.0784
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9768
# ...loss: 0.0783
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9768
# ...loss: 0.0783
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9769
# ...loss: 0.0781
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9769
# ...loss: 0.0780
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9768
# ...loss: 0.0786
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9768
# ...loss: 0.0784
# Results at the end of the batch
# ...sparse_categorical_accuracy: 0.9768
# ...loss: 0.0785
# Results at the end of epoch 2
# ...sparse_categorical_accuracy: 0.9768
# ...loss: 0.0785

# %%
@tf.function # CPU 에서 돌아가서 느린 걸 GPU에서 작동하게 변환
def test_step(inputs, targets):
    predictions = model(inputs, training=False)
    loss = loss_fn(targets, predictions)

    logs = {}
    for metric in metrics:
        metric.update_state(targets, predictions)
        logs["val_" + metric.name] = metric.result()

    loss_tracking_metric.update_state(loss)
    logs["val_loss"] = loss_tracking_metric.result()
    return logs

val_dataset = tf.data.Dataset.from_tensor_slices((val_images, val_labels))
val_dataset = val_dataset.batch(32)
reset_metrics()
for inputs_batch, targets_batch in val_dataset:
    logs = test_step(inputs_batch, targets_batch)
print("Evaluation results:")
for key, value in logs.items():
    print(f"...{key}: {value:.4f}")
# Out:
# Evaluation results:
# ...val_sparse_categorical_accuracy: 0.9650
# ...val_loss: 0.1278
